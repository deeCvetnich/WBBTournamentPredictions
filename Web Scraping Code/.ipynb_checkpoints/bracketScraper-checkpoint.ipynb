# %%
import requests
import re
from bs4 import BeautifulSoup

#make array of game urls
gameUrls = []
urlBase = "https://www.ncaa.com/game/"
urlStart = 5981645
urlEnd = 5981711
for i in range(urlStart, urlEnd+1):
    gameUrls.append(urlBase + str(i))

# %%
def getPageData(URL):
    #URL = gameUrls[5]
    page = requests.get(URL)

    soup = BeautifulSoup(page.content, "html.parser")

    roundNumber = soup.find_all("h2", class_="title")
    
    #should only have one element
    if(len(roundNumber)>1):
        return -100
    string = str(roundNumber[0])
    
    # using split() to extract words from string
    res = string.split()

    # printing result
    print(res[8])
    
for i in range(len(gameUrls)):
    getPageData(gameUrls[i])
# Out:
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# First
# Second
# Second
# Second
# Second
# Second
# Second
# Second
# Second
# Second
# Second
# Second
# Second
# Second
# Second
# Second
# Second
# Sweet
# Sweet
# Sweet
# Sweet
# Sweet
# Sweet
# Sweet
# Sweet
# Elite
# Elite
# Elite
# Elite
# FINAL
# FINAL
# Championship</h2>
